# %% [markdown]
# ## Library

# %% [markdown]
# ####Install Library

# %%
# %%capture
# !pip install snscrape

# %% [markdown]
# #### Import Library

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import csv
import re
import nltk
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import string 
import re #regex library

# %% [markdown]
# ## Crawling

# %%
def crawler(tweets, no_query, limit):
  for i,tweet in enumerate(sntwitter.TwitterSearchScraper(no_query).get_items()):
      if i > limit:
        break
      tweets.append([tweet.date, jenis, tweet.username, tweet.content])

# %%
#list tweet
tweets = [] 

#Jenis HP
jenis = 'iphone' 

# Aspek Kamera
query1 = ('kamera ' + jenis + ' lang:id')
query2 = ('jernih ' + jenis + ' lang:id')
query3 = ('bagus ' + jenis + ' lang:id')
query4 = ('keren ' + jenis + ' lang:id')
query5 = ('kualitas foto' + jenis + ' lang:id')
query6 = ('kualitas video' + jenis + ' lang:id')

# Aspek Baterai
query7 = ('baterai ' + jenis + ' lang:id')
query8 = ('boros ' + jenis + ' lang:id')
query9 = ('hemat' + jenis + ' lang:id')
query10 = ('awet' + jenis + ' lang:id')
query11 = ('rusak' + jenis + ' lang:id')

# Aspek Desain
query12 = ('tipis' + jenis + ' lang:id')
query13 = ('tebal' + jenis + ' lang:id')
query14 = ('desain' + jenis + ' lang:id')
query15 = ('layar' + jenis + ' lang:id')
query16 = ('body' + jenis + ' lang:id')

# Aspek Harga
query17 = ('harga' + jenis + ' lang:id')
query18 = ('mahal' + jenis + ' lang:id')
query19 = ('murah' + jenis + ' lang:id')

# Aspek Spesifikasi
query20 = ('ram' + jenis + ' lang:id')
query21 = ('spesifikasi' + jenis + ' lang:id')
query22 = ('kecepatan processor' + jenis + ' lang:id')
query23 = ('chipset' + jenis + ' lang:id')
#total tweet
limit = 3000


# crawling

# %time
# Aspek Kamera
crawler(tweets, query1, limit)
crawler(tweets, query2, limit)
crawler(tweets, query3, limit)
crawler(tweets, query4, limit)
crawler(tweets, query5, limit)
crawler(tweets, query6, limit)

# Aspek Baterai
crawler(tweets, query7, limit)
crawler(tweets, query8, limit)
crawler(tweets, query9, limit)
crawler(tweets, query10, limit)
crawler(tweets, query11, limit)

# Aspek Desain
crawler(tweets, query12, limit)
crawler(tweets, query13, limit)
crawler(tweets, query14, limit)
crawler(tweets, query15, limit)
crawler(tweets, query16, limit)

# Aspek Harga
crawler(tweets, query17, limit)
crawler(tweets, query18, limit)
crawler(tweets, query19, limit)

# Aspek Spesifikasi
crawler(tweets, query20, limit)
crawler(tweets, query21, limit)
crawler(tweets, query22, limit)
crawler(tweets, query23, limit)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.54 µs

# %%
tweets
# Out:
# [[datetime.datetime(2022, 10, 29, 3, 19, 38, tzinfo=datetime.timezone.utc),
#   'iphone',
#   'Greentearolcake',
#   '@orenjirommm Ra, gw muk tanya. Kamera nya iPhone tuh paling tinggi berapa mp?'],
#  [datetime.datetime(2022, 10, 29, 1, 44, 39, tzinfo=datetime.timezone.utc),
#   'iphone',
#   'thefaizzainal',
#   'Nampaknya ramai pilih gambar 1 &amp; 2. Tapi ada juga yang teka betul. Jawapannya :\n\n🏆- Pixel 7 Pro\n2- Nothing Phone (1)\n3- Mate 50 Pro\n4- iPhone 14 Pro Max\n\nStruggle juga nak fokus guna kamera iPhone. Dalam 3-4 kali ambil, dapat hasil sama. Tu je paling okay.\n\nNantikan test lain... https://t.co/YivvMKoaiK'],
#  [datetime.datetime(2022, 10, 29, 1, 12, 51, tzinfo=datetime.timezone.utc),
#   'iphone',
#   'toraobinn',
#   'Pake iphone enak gak si\nAku pengen punya kamera sebagus ip :")\nTapi duitnya gak sanggup haha'],
#  [datetime.datetime(2022, 10, 29, 1, 5, 7, tzinfo=datetime.timezone.utc),
#   'iphone',
#   'shishiliu23',
# ...

# %%
#Dataframe
df = pd.DataFrame(tweets, columns=['date', 'jenis', 'username', 'tweet'])
df.shape
# Out:
# (18312, 4)

# %%
df
# Out:
#                            date   jenis         username  \
# 0     2022-10-29 03:19:38+00:00  iphone  Greentearolcake
# 1     2022-10-29 01:44:39+00:00  iphone    thefaizzainal
# 2     2022-10-29 01:12:51+00:00  iphone        toraobinn
# 3     2022-10-29 01:05:07+00:00  iphone      shishiliu23
# 4     2022-10-29 00:31:38+00:00  iphone       John__Tedy
# ...                         ...     ...              ...
# 18307 2020-08-10 01:54:09+00:00  iphone    Onlenpediacom
# 18308 2017-03-25 04:48:59+00:00  iphone        bossharga
# 18309 2017-03-25 04:48:27+00:00  iphone        bossharga
# 18310 2015-01-02 03:32:03+00:00  iphone  alettertoelisse
# 18311 2012-09-10 10:00:14+00:00  iphone        akiasmoro
#
#                                                    tweet
# 0      @orenjirommm Ra, gw muk tanya. Kamera nya iPho...
# 1      Nampaknya ramai pilih gambar 1 &amp; 2. Tapi a...
# 2      Pake iphone enak gak si\nAku pengen punya kame...
# ...

# %%
def remove_tweet_special(text):
  # remove mention @
    text = re.sub(r"[@][\w_-]+","", text)
    # remove link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
  # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
df['cleansing'] = df['tweet'].apply(remove_tweet_special)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18307    False
# 18308     True
# 18309     True
# 18310    False
# 18311    False
# Length: 18312, dtype: bool

# %%
df.drop_duplicates(subset='tweet', keep=False, inplace=True)
df = df.reset_index(drop=True)

df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16110    False
# 16111    False
# 16112    False
# 16113    False
# 16114    False
# Length: 16115, dtype: bool

# %%
df.shape
# Out:
# (16115, 5)

# %% [markdown]
# ####Export CSV

# %%
df.to_csv('Iphone.csv', index=False)
